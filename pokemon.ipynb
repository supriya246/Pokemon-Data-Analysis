# %%
import pandas as pd
df= pd.read_csv('pokedex_(update.04.20).csv')
print(df.head(3))
# Out:
#    Unnamed: 0  pokedex_number       name  generation  legendary type 1  \
# 0           0               1  Bulbasaur           1          0  Grass
# 1           1               2    Ivysaur           1          0  Grass
# 2           2               3   Venusaur           1          0  Grass
#
#    type 2    hp  attack  defense  sp_attack  sp_defense  speed
# 0  Poison  45.0    49.0     49.0       65.0        65.0   45.0
# 1  Poison  60.0    62.0     63.0       80.0        80.0   60.0
# 2  Poison  80.0    82.0     83.0      100.0       100.0   80.0

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'pokedex_number', 'name', 'generation', 'legendary',
#        'type 1', 'type 2', 'hp', 'attack', 'defense', 'sp_attack',
#        'sp_defense', 'speed'],
#       dtype='object')

# %%
print(df[['name','type 1', 'hp']])
# Out:
#                                 name    type 1     hp
# 0                          Bulbasaur     Grass   45.0
# 1                            Ivysaur     Grass   60.0
# 2                           Venusaur     Grass   80.0
# 3                      Mega Venusaur     Grass   80.0
# 4                         Charmander      Fire   39.0
# ...                              ...       ...    ...
# 1023     Zacian Hero of Many Battles     Fairy   92.0
# 1024        Zamazenta Crowned Shield  Fighting   92.0
# 1025  Zamazenta Hero of Many Battles  Fighting   92.0
# 1026                       Eternatus    Poison  140.0
# 1027             Eternatus Eternamax    Poison  255.0
#
# [1028 rows x 3 columns]

# %%
print(df.iloc[1])
# Out:
# Unnamed: 0              1
# pokedex_number          2
# name              Ivysaur
# generation              1
# legendary               0
# type 1              Grass
# type 2             Poison
# hp                   60.0
# attack               62.0
# defense              63.0
# sp_attack            80.0
# sp_defense           80.0
# speed                60.0
# Name: 1, dtype: object

# %%
print(df.iloc[1:4])
# Out:
#    Unnamed: 0  pokedex_number           name  generation  legendary type 1  \
# 1           1               2        Ivysaur           1          0  Grass
# 2           2               3       Venusaur           1          0  Grass
# 3           3               3  Mega Venusaur           1          0  Grass
#
#    type 2    hp  attack  defense  sp_attack  sp_defense  speed
# 1  Poison  60.0    62.0     63.0       80.0        80.0   60.0
# 2  Poison  80.0    82.0     83.0      100.0       100.0   80.0
# 3  Poison  80.0   100.0    123.0      122.0       120.0   80.0

# %%
print(df.iloc[2,1])
# Out:
# 3

# %%
df.loc[df['type 1'] == 'Fire']
# Out:
#      Unnamed: 0  pokedex_number              name  generation  legendary  \
# 4             4               4        Charmander           1          0
# 5             5               5        Charmeleon           1          0
# 6             6               6         Charizard           1          0
# 7             7               6  Mega Charizard X           1          0
# 8             8               6  Mega Charizard Y           1          0
# ..          ...             ...               ...         ...        ...
# 943         943             813         Scorbunny           8          0
# 944         944             814            Raboot           8          0
# 945         945             815         Cinderace           8          0
# 981         981             850        Sizzlipede           8          0
# 982         982             851       Centiskorch           8          0
#
#     type 1  type 2     hp  attack  defense  sp_attack  sp_defense  speed
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  pokedex_number   generation    legendary           hp  \
# count  1028.000000     1028.000000  1028.000000  1028.000000  1027.000000
# mean    513.500000      437.711089     4.034047     0.037938    69.587147
# std     296.902341      259.366480     2.234937     0.191139    26.397009
# min       0.000000        1.000000     1.000000     0.000000     1.000000
# 25%     256.750000      213.750000     2.000000     0.000000    50.000000
# 50%     513.500000      433.500000     4.000000     0.000000    67.000000
# 75%     770.250000      663.250000     6.000000     0.000000    80.000000
# max    1027.000000      890.000000     8.000000     1.000000   255.000000
#
#             attack      defense    sp_attack   sp_defense        speed
# count  1027.000000  1027.000000  1027.000000  1027.000000  1027.000000
# mean     80.114898    74.507303    72.720545    72.161636    68.512171
# std      32.387734    31.302129    32.691374    28.081599    29.808365
# ...

# %%
df.sort_values(['type 1', 'hp'], ascending= False)
# Out:
#      Unnamed: 0  pokedex_number       name  generation  legendary type 1  \
# 380         380             321    Wailord           3          0  Water
# 692         692             594  Alomomola           5          0  Water
# 167         167             131     Lapras           1          0  Water
# 171         171             134   Vaporeon           1          0  Water
# 379         379             320    Wailmer           3          0  Water
# ..          ...             ...        ...         ...        ...    ...
# 893         893             767     Wimpod           7          0    Bug
# 954         954             824    Blipbug           8          0    Bug
# 256         256             213    Shuckle           2          0    Bug
# 345         345             292   Shedinja           3          0    Bug
# 240         240             199   Slowking           2          0    NaN
#
#     type 2     hp  attack  defense  sp_attack  sp_defense  speed
# ...

# %%
df.sort_values(['name','type 1'],ascending= [1,0])
# Out:
#      Unnamed: 0  pokedex_number                    name  generation  \
# 542         542             460               Abomasnow           4
# 81           81              63                    Abra           1
# 424         424             359                   Absol           3
# 715         715             617                Accelgor           5
# 789         789             681   Aegislash Blade Forme           6
# ..          ...             ...                     ...         ...
# 54           54              41                   Zubat           1
# 733         733             634                Zweilous           5
# 834         834             718       Zygarde 10% Forme           6
# 833         833             718       Zygarde 50% Forme           6
# 835         835             718  Zygarde Complete Forme           6
#
#      legendary   type 1  type 2     hp  attack  defense  sp_attack  \
# 542          0    Grass     Ice   90.0    92.0     75.0       92.0
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0  pokedex_number           name  generation  legendary type 1  \
# 0           0               1      Bulbasaur           1          0  Grass
# 1           1               2        Ivysaur           1          0  Grass
# 2           2               3       Venusaur           1          0  Grass
# 3           3               3  Mega Venusaur           1          0  Grass
# 4           4               4     Charmander           1          0   Fire
#
#    type 2    hp  attack  defense  sp_attack  sp_defense  speed
# 0  Poison  45.0    49.0     49.0       65.0        65.0   45.0
# 1  Poison  60.0    62.0     63.0       80.0        80.0   60.0
# 2  Poison  80.0    82.0     83.0      100.0       100.0   80.0
# 3  Poison  80.0   100.0    123.0      122.0       120.0   80.0
# 4     NaN  39.0    52.0     43.0       60.0        50.0   65.0

# %%
df['Total']= df['hp']+df['attack']+df['defense']+df['sp_attack']+df['sp_defense']+df['speed']
df.head(5)
# Out:
#    Unnamed: 0  pokedex_number           name  generation  legendary type 1  \
# 0           0               1      Bulbasaur           1          0  Grass
# 1           1               2        Ivysaur           1          0  Grass
# 2           2               3       Venusaur           1          0  Grass
# 3           3               3  Mega Venusaur           1          0  Grass
# 4           4               4     Charmander           1          0   Fire
#
#    type 2    hp  attack  defense  sp_attack  sp_defense  speed  Total
# 0  Poison  45.0    49.0     49.0       65.0        65.0   45.0  318.0
# 1  Poison  60.0    62.0     63.0       80.0        80.0   60.0  405.0
# 2  Poison  80.0    82.0     83.0      100.0       100.0   80.0  525.0
# 3  Poison  80.0   100.0    123.0      122.0       120.0   80.0  625.0
# 4     NaN  39.0    52.0     43.0       60.0        50.0   65.0  309.0

# %%
df['Total']= df.iloc[:,7:13].sum(axis=1)
df.head(5)
# Out:
#    Unnamed: 0  pokedex_number           name  generation  legendary type 1  \
# 0           0               1      Bulbasaur           1          0  Grass
# 1           1               2        Ivysaur           1          0  Grass
# 2           2               3       Venusaur           1          0  Grass
# 3           3               3  Mega Venusaur           1          0  Grass
# 4           4               4     Charmander           1          0   Fire
#
#    type 2    hp  attack  defense  sp_attack  sp_defense  speed  Total
# 0  Poison  45.0    49.0     49.0       65.0        65.0   45.0  318.0
# 1  Poison  60.0    62.0     63.0       80.0        80.0   60.0  405.0
# 2  Poison  80.0    82.0     83.0      100.0       100.0   80.0  525.0
# 3  Poison  80.0   100.0    123.0      122.0       120.0   80.0  625.0
# 4     NaN  39.0    52.0     43.0       60.0        50.0   65.0  309.0

# %%
df.to_csv('modified.csv', index= False)

# %%
df.loc[df['type 1']== 'Grass']
# Out:
#      Unnamed: 0  pokedex_number           name  generation  legendary type 1  \
# 0             0               1      Bulbasaur           1          0  Grass
# 1             1               2        Ivysaur           1          0  Grass
# 2             2               3       Venusaur           1          0  Grass
# 3             3               3  Mega Venusaur           1          0  Grass
# 56           56              43         Oddish           1          0  Grass
# ..          ...             ...            ...         ...        ...    ...
# 959         959             829     Gossifleur           8          0  Grass
# 960         960             830       Eldegoss           8          0  Grass
# 970         970             840         Applin           8          0  Grass
# 971         971             841        Flapple           8          0  Grass
# 972         972             842       Appletun           8          0  Grass
#
# ...

# %%
df.loc[(df['type 1']=='Grass')& (df['type 2']== 'Poison')& (df['hp'] > 70)]
# Out:
#      Unnamed: 0  pokedex_number           name  generation  legendary type 1  \
# 2             2               3       Venusaur           1          0  Grass
# 3             3               3  Mega Venusaur           1          0  Grass
# 58           58              45      Vileplume           1          0  Grass
# 90           90              71     Victreebel           1          0  Grass
# 689         689             591      Amoonguss           5          0  Grass
#
#      type 2     hp  attack  defense  sp_attack  sp_defense  speed  Total
# 2    Poison   80.0    82.0     83.0      100.0       100.0   80.0  525.0
# 3    Poison   80.0   100.0    123.0      122.0       120.0   80.0  625.0
# 58   Poison   75.0    80.0     85.0      110.0        90.0   50.0  490.0
# 90   Poison   80.0   105.0     65.0      100.0        70.0   70.0  490.0
# 689  Poison  114.0    85.0     70.0       85.0        80.0   30.0  464.0

# %%
df.loc[df['name'].str.contains('Mega')]
# Out:
#      Unnamed: 0  pokedex_number              name  generation  legendary  \
# 3             3               3     Mega Venusaur           1          0
# 7             7               6  Mega Charizard X           1          0
# 8             8               6  Mega Charizard Y           1          0
# 12           12               9    Mega Blastoise           1          0
# 19           19              15     Mega Beedrill           1          0
# 23           23              18      Mega Pidgeot           1          0
# 84           84              65     Mega Alakazam           1          0
# 105         105              80      Mega Slowbro           1          0
# 123         123              94       Mega Gengar           1          0
# 148         148             115   Mega Kangaskhan           1          0
# 162         162             127       Mega Pinsir           1          0
# 166         166             130     Mega Gyarados           1          0
# ...

# %%
df.loc[~df['name'].str.contains('Mega')]
# Out:
#       Unnamed: 0  pokedex_number                            name  generation  \
# 0              0               1                       Bulbasaur           1
# 1              1               2                         Ivysaur           1
# 2              2               3                        Venusaur           1
# 4              4               4                      Charmander           1
# 5              5               5                      Charmeleon           1
# ...          ...             ...                             ...         ...
# 1023        1023             888     Zacian Hero of Many Battles           8
# 1024        1024             889        Zamazenta Crowned Shield           8
# 1025        1025             889  Zamazenta Hero of Many Battles           8
# 1026        1026             890                       Eternatus           8
# 1027        1027             890             Eternatus Eternamax           8
#
# ...

# %%
import re
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 import re
# ----> 2 df.loc[df['type 1'].str.contains('dragon', flags= re.I,regex=True)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1324, in _LocIndexer._getitem_axis(self, key, axis)
#    1322     self._validate_key(key, axis)
#    1323     return self._get_slice_axis(key, axis=axis)
# -> 1324 elif com.is_bool_indexer(key):
#    1325     return self._getbool_axis(key, axis=axis)
#    1326 elif is_list_like_indexer(key):
#    1327     # an iterable multi-selection
#
# ...

# %%
df.loc[df['type 1'].str.contains('dragon', flags= re.I,regex=True)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df.loc[df['type 1'].str.contains('dragon', flags= re.I,regex=True)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1324, in _LocIndexer._getitem_axis(self, key, axis)
#    1322     self._validate_key(key, axis)
#    1323     return self._get_slice_axis(key, axis=axis)
# -> 1324 elif com.is_bool_indexer(key):
#    1325     return self._getbool_axis(key, axis=axis)
#    1326 elif is_list_like_indexer(key):
#    1327     # an iterable multi-selection
#
# ...

# %%
df.loc[df['name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)]
# Out:
#       Unnamed: 0  pokedex_number        name  generation  legendary    type 1  \
# 20            20              16      Pidgey           1          0    Normal
# 21            21              17   Pidgeotto           1          0    Normal
# 22            22              18     Pidgeot           1          0    Normal
# 32            32              25     Pikachu           1          0  Electric
# 161          161             127      Pinsir           1          0       Bug
# 212          212             172       Pichu           2          0  Electric
# 245          245             204      Pineco           2          0       Bug
# 265          265             221   Piloswine           2          0       Ice
# 470          470             393      Piplup           4          0     Water
# 590          590             499     Pignite           5          0      Fire
# 610          610             519      Pidove           5          0    Normal
# ...

# %%
df.loc[df['type 1']== 'Fire','type 1']= 'Flamer'
df
# Out:
#       Unnamed: 0  pokedex_number                            name  generation  \
# 0              0               1                       Bulbasaur           1
# 1              1               2                         Ivysaur           1
# 2              2               3                        Venusaur           1
# 3              3               3                   Mega Venusaur           1
# 4              4               4                      Charmander           1
# ...          ...             ...                             ...         ...
# 1023        1023             888     Zacian Hero of Many Battles           8
# 1024        1024             889        Zamazenta Crowned Shield           8
# 1025        1025             889  Zamazenta Hero of Many Battles           8
# 1026        1026             890                       Eternatus           8
# 1027        1027             890             Eternatus Eternamax           8
#
# ...

# %%
df.loc[df['type 1']=='Flamer','type 1']='Fire'
df
# Out:
#       Unnamed: 0  pokedex_number                            name  generation  \
# 0              0               1                       Bulbasaur           1
# 1              1               2                         Ivysaur           1
# 2              2               3                        Venusaur           1
# 3              3               3                   Mega Venusaur           1
# 4              4               4                      Charmander           1
# ...          ...             ...                             ...         ...
# 1023        1023             888     Zacian Hero of Many Battles           8
# 1024        1024             889        Zamazenta Crowned Shield           8
# 1025        1025             889  Zamazenta Hero of Many Battles           8
# 1026        1026             890                       Eternatus           8
# 1027        1027             890             Eternatus Eternamax           8
#
# ...

# %%
df.loc[df['type 1']=='Fire','Legendary']= True
df
# Out:
#       Unnamed: 0  pokedex_number                            name  generation  \
# 0              0               1                       Bulbasaur           1
# 1              1               2                         Ivysaur           1
# 2              2               3                        Venusaur           1
# 3              3               3                   Mega Venusaur           1
# 4              4               4                      Charmander           1
# ...          ...             ...                             ...         ...
# 1023        1023             888     Zacian Hero of Many Battles           8
# 1024        1024             889        Zamazenta Crowned Shield           8
# 1025        1025             889  Zamazenta Hero of Many Battles           8
# 1026        1026             890                       Eternatus           8
# 1027        1027             890             Eternatus Eternamax           8
#
# ...

# %%
df.loc[df['Total']>500,['Generation', 'Legendary']]=['Test 1','Test 2']
df
# Out:
#       Unnamed: 0  pokedex_number                            name  generation  \
# 0              0               1                       Bulbasaur           1
# 1              1               2                         Ivysaur           1
# 2              2               3                        Venusaur           1
# 3              3               3                   Mega Venusaur           1
# 4              4               4                      Charmander           1
# ...          ...             ...                             ...         ...
# 1023        1023             888     Zacian Hero of Many Battles           8
# 1024        1024             889        Zamazenta Crowned Shield           8
# 1025        1025             889  Zamazenta Hero of Many Battles           8
# 1026        1026             890                       Eternatus           8
# 1027        1027             890             Eternatus Eternamax           8
#
# ...

# %%
df=pd.read_csv('modified.csv')
df
# Out:
#       Unnamed: 0  pokedex_number                            name  generation  \
# 0              0               1                       Bulbasaur           1
# 1              1               2                         Ivysaur           1
# 2              2               3                        Venusaur           1
# 3              3               3                   Mega Venusaur           1
# 4              4               4                      Charmander           1
# ...          ...             ...                             ...         ...
# 1023        1023             888     Zacian Hero of Many Battles           8
# 1024        1024             889        Zamazenta Crowned Shield           8
# 1025        1025             889  Zamazenta Hero of Many Battles           8
# 1026        1026             890                       Eternatus           8
# 1027        1027             890             Eternatus Eternamax           8
#
# ...

# %%
df=pd.read_csv('modified.csv')
df.groupby(['type 1']).count()
# Out:
#           Unnamed: 0  pokedex_number  name  generation  legendary  type 2  \
# type 1
# Bug               81              81    81          81         81      62
# Dark              43              43    43          43         43      29
# Dragon            40              40    40          40         40      28
# Electric          61              61    61          61         61      28
# Fairy             22              22    22          22         22       3
# Fighting          38              38    38          38         38      10
# Fire              65              65    65          65         65      31
# Flying             8               8     8           8          8       4
# Ghost             41              41    41          41         41      27
# Grass             91              91    91          91         91      48
# Ground            41              41    41          41         41      24
# Ice               36              36    36          36         36      17
# ...

# %%
df['count']= 1
df.groupby(['type 1']).count()['count']
# Out:
# type 1
# Bug          81
# Dark         43
# Dragon       40
# Electric     61
# Fairy        22
# Fighting     38
# Fire         65
# Flying        8
# Ghost        41
# Grass        91
# Ground       41
# Ice          36
# Normal      115
# Poison       39
# Psychic      76
# Rock         60
# Steel        36
# Water       134
# Name: count, dtype: int64

# %%
df.groupby(['type 1','type 2']).count()['count']
# Out:
# type 1  type 2
# Bug     Electric     4
#         Fairy        2
#         Fighting     4
#         Fire         2
#         Flying      14
#                     ..
# Water   Ice          4
#         Poison       3
#         Psychic      6
#         Rock         5
#         Steel        1
# Name: count, Length: 171, dtype: int64

# %%
for df in pd.read_csv('modified.csv', chunksize=5):
    print("CHUNK DF")
    print(df)
# Out:
# CHUNK DF
#    Unnamed: 0  pokedex_number           name  generation  legendary type 1  \
# 0           0               1      Bulbasaur           1          0  Grass
# 1           1               2        Ivysaur           1          0  Grass
# 2           2               3       Venusaur           1          0  Grass
# 3           3               3  Mega Venusaur           1          0  Grass
# 4           4               4     Charmander           1          0   Fire
#
#    type 2    hp  attack  defense  sp_attack  sp_defense  speed  Total
# 0  Poison  45.0    49.0     49.0       65.0        65.0   45.0  318.0
# 1  Poison  60.0    62.0     63.0       80.0        80.0   60.0  405.0
# 2  Poison  80.0    82.0     83.0      100.0       100.0   80.0  525.0
# 3  Poison  80.0   100.0    123.0      122.0       120.0   80.0  625.0
# 4     NaN  39.0    52.0     43.0       60.0        50.0   65.0  309.0
# CHUNK DF
# ...
